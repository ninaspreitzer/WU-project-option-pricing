# %%
# Defining new environment variable 'PYSPARK_SUBMIT_ARGS' 
import os, sys
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.mongodb.spark:mongo-spark-connector_2.11:2.4.0 --jars /usr/local/jar_files/spark-streaming-kafka-0-8-assembly_2.11-2.3.2.jar pyspark-shell'

# %%
# Import findspark 
import findspark

# Initialize and provide path
findspark.init("/usr/share/spark/spark-2.3.2-bin-hadoop2.7/")

# %%
##   Importing Spark Libraries
#    Spark
from pyspark import SparkContext
#    Spark Streaming
from pyspark.streaming import StreamingContext
#    Kafka
from pyspark.streaming.kafka import KafkaUtils
#    KafkaConsumer
from kafka import KafkaConsumer

##   Additional Libraries
#    Calculation methods
from pyspark.sql import functions as F
from  pyspark.sql.functions import abs
from  pyspark.sql.functions import log
from pyspark.sql.types import DateType
from pyspark.sql.functions import stddev
from pyspark.sql.functions import sqrt
from scipy.stats import norm
import math
import numpy as np
#     User defined function, in order to use (norm.cdf) from scipy.stats
from pyspark.sql.functions import udf

# %%
# Import SparkSession
from pyspark.sql import SparkSession

#    Build the SparkSession
spark = SparkSession.builder \
    .master("local") \
    .appName("master_consumer") \
    .config("spark.mongodb.input.uri", "mongodb://localhost/stocks_db.stock_coll") \
    .config("spark.mongodb.output.uri", "mongodb://localhost/stocks_db.stock_coll") \
    .getOrCreate()
   
#    Create SparkContext
sc = spark.sparkContext
#    Set SparkContext Interval to 10
sc.setLogLevel("WARN")
ssc = StreamingContext(sc, 10)

# %%
#    Import Spark SQL and Row
from pyspark.sql import Row,SQLContext

#    Function that defines SQLContext
def get_sql_context_instance(spark_context):
    if ('sqlContextSingletonInstance' not in globals()):
        globals()['sqlContextSingletonInstance'] = SQLContext(spark_context)
    return globals()['sqlContextSingletonInstance']

# %%
#    PyMongo for MongoDB
import pymongo

def write_mongo(df):
    try:
        # Append the input df to the database
        df.write.format("com.mongodb.spark.sql.DefaultSource").mode("append").save()
    except:
        e = sys.exc_info()[0]
        print("Mongo Error: %s" % e)

# %%
stockData = spark.read.format("com.mongodb.spark.sql.DefaultSource").option("uri","mongodb://localhost/stocks_db.stockhist_coll").load()
stockData  = stockData.drop("close", "high", "low", "open", "volumne", "frequency", "intraperiod")
stockData = stockData.withColumn("date", stockData["date"].cast(DateType()))
stockData.createOrReplaceTempView("AAPL")
stockData = spark.sql("SELECT * FROM AAPL WHERE date BETWEEN '2019-01-01' AND '2020-01-01'")
stockData = stockData.withColumn("volatility", abs(stockData["adj_close"]/stockData["prev_close"]-1))
stockData.show(truncate=False)
meanVol = stockData.select(stddev("volatility")*math.sqrt(252)).take(1)[0][0]
# Out:
# +--------------------------+---------+--------+--------+--------+-----------+----------+----------+-----------+---------------------+
# |_id                       |adj_close|adj_high|adj_low |adj_open|adj_volume |date      |prev_close|volume     |volatility           |
# +--------------------------+---------+--------+--------+--------+-----------+----------+----------+-----------+---------------------+
# |[5e3d35671bc8b17f7ef416e4]|293.65   |293.68  |289.52  |289.93  |2.5247625E7|2019-12-31|291.52    |2.5247625E7|0.0073065312843030306|
# |[5e3d35671bc8b17f7ef416e5]|291.52   |292.69  |285.22  |289.46  |3.6059614E7|2019-12-30|289.8     |3.6059614E7|0.005935127674258078 |
# |[5e3d35671bc8b17f7ef416e6]|289.8    |293.97  |288.12  |291.12  |3.6592936E7|2019-12-27|289.91    |3.6592936E7|3.794280983754339E-4 |
# |[5e3d35671bc8b17f7ef416e7]|289.91   |289.98  |284.7   |284.82  |2.3334004E7|2019-12-26|284.27    |2.3334004E7|0.019840292679494942 |
# |[5e3d35671bc8b17f7ef416e8]|284.27   |284.89  |282.9197|284.69  |1.2119714E7|2019-12-24|284.0     |1.2119714E7|9.507042253520392E-4 |
# |[5e3d35671bc8b17f7ef416e9]|284.0    |284.25  |280.3735|280.53  |2.4677883E7|2019-12-23|279.44    |2.4677883E7|0.016318350987689634 |
# |[5e3d35671bc8b17f7ef416ea]|279.44   |282.65  |278.56  |282.23  |6.9032743E7|2019-12-20|280.02    |6.9032743E7|0.002071280622812588 |
# |[5e3d35671bc8b17f7ef416eb]|280.02   |281.18  |278.95  |279.5   |2.4626947E7|2019-12-19|279.74    |2.4626947E7|0.0010009294344748287|
# |[5e3d35671bc8b17f7ef416ec]|279.74   |281.9   |279.12  |279.8   |2.9024687E7|2019-12-18|280.41    |2.9024687E7|0.002389358439428002 |
# |[5e3d35671bc8b17f7ef416ed]|280.41   |281.77  |278.8   |279.57  |2.8575798E7|2019-12-17|279.86    |2.8575798E7|0.001965268348459892 |
# |[5e3d35671bc8b17f7ef416ee]|279.86   |280.79  |276.98  |277.0   |3.2081105E7|2019-12-16|275.15    |3.2081105E7|0.017117935671452145 |
# |[5e3d35671bc8b17f7ef416ef]|275.15   |275.3   |270.93  |271.46  |3.3432806E7|2019-12-13|271.46    |3.3432806E7|0.01359316289692769  |
# |[5e3d35671bc8b17f7ef416f0]|271.46   |272.5599|267.321 |267.78  |3.4437042E7|2019-12-12|270.77    |3.4437042E7|0.002548288215090233 |
# |[5e3d35671bc8b17f7ef416f1]|270.77   |271.1   |268.5   |268.81  |1.9723391E7|2019-12-11|268.48    |1.9723391E7|0.008529499404052343 |
# |[5e3d35671bc8b17f7ef416f2]|268.48   |270.07  |265.86  |268.6   |2.2632383E7|2019-12-10|266.92    |2.2632383E7|0.0058444477746140144|
# |[5e3d35671bc8b17f7ef416f3]|266.92   |270.8   |264.91  |270.0   |3.2182645E7|2019-12-09|270.71    |3.2182645E7|0.01400022163939263  |
# |[5e3d35671bc8b17f7ef416f4]|270.71   |271.0   |267.3   |267.48  |2.6547493E7|2019-12-06|265.58    |2.6547493E7|0.01931621357029889  |
# |[5e3d35671bc8b17f7ef416f5]|265.58   |265.89  |262.73  |263.79  |1.8661343E7|2019-12-05|261.74    |1.8661343E7|0.014671047604492893 |
# |[5e3d35671bc8b17f7ef416f6]|261.74   |263.31  |260.68  |261.07  |1.6810388E7|2019-12-04|259.45    |1.6810388E7|0.00882636346116783  |
# |[5e3d35671bc8b17f7ef416f7]|259.45   |259.53  |256.29  |258.31  |2.9377268E7|2019-12-03|264.16    |2.9377268E7|0.01783010296789833  |
# +--------------------------+---------+--------+--------+--------+-----------+----------+----------+-----------+---------------------+
# only showing top 20 rows

# %%
##    Defining external variables
#     Expiration time in months
T = 1/12
#     Square root of expiration time
T_s = (1/12)**0.5
#     Risk-free rate (constant  ->  source: https://www.statista.com/statistics/885892/average-risk-free-rate-austria/)
r = 0.013
#     Annualized historical volatility to the power of 2 (Assumption 252 Trading day) 
#     set: 02-07-2020 till 01-01-2019
meanVolPow = meanVol**2
# Euler's number to the power of the negative risk-free rate times the expiration time
eu_exp = np.exp(-r * T)


def getOptionPrices(time, rdd):
    
    try:
        # Get SparkSQLContext from the current context
        sql_context = get_sql_context_instance(rdd.context)
        
        # Convert RDD to Row RDD
        row_rdd = rdd.map(lambda w: Row( updated_on=w['updated_on'], ticker=w['ticker'], last_price=w['last_price'], prev_price=w["prev_price"])) 
        # Create a DF of the Row RDD
        df = sql_context.createDataFrame(row_rdd)
        
        # Insert d1 and d2 for:
        #     out-of-the-money option (OTM)
        df = df.withColumn("d1_otm", (log(df["last_price"]/(df["last_price"]+20))+(r + 0.5 * meanVolPow)*T) / (meanVol * T_s))
        df = df.withColumn("d1_otm", (log(df["last_price"]/(df["last_price"]+20))+(r + 0.5 * meanVolPow)*T) / (meanVol * T_s))
        df = df.withColumn("d2_otm", (df["d1_otm"]-(meanVol * T_s)))
        #     at-the-money option (ATM)
        df = df.withColumn("d1_atm", (log(df["last_price"]/df["last_price"])+(r + 0.5 * meanVolPow)*T) / (meanVol * T_s))
        df = df.withColumn("d1_atm", (log(df["last_price"]/df["last_price"])+(r + 0.5 * meanVolPow)*T) / (meanVol * T_s))
        df = df.withColumn("d2_atm", (df["d1_atm"]-(meanVol * T_s)))
        #     in-the-money option (ITM)
        df = df.withColumn("d1_itm", (log(df["last_price"]/(df["last_price"]-20))+(r + 0.5 * meanVolPow)*T) / (meanVol * T_s))
        df = df.withColumn("d1_itm", (log(df["last_price"]/(df["last_price"]-20))+(r + 0.5 * meanVolPow)*T) / (meanVol * T_s))
        df = df.withColumn("d2_itm", (df["d1_itm"]-(meanVol * T_s)))
        
        # Creating "User Defined Function" in Spark, applying the cumulative distributed function for normal distributions on input variable x
        norm_cdf = udf(lambda x: float(norm.cdf(x)))
        
        # Calculating probabilities for d1 and d2 (cumulative distribution function)
        #     out-of-the-money option (OTM)
        df = df.withColumn("d1_otm_cdf", norm_cdf(df['d1_otm']))
        df = df.withColumn("d2_otm_cdf", norm_cdf(df['d2_otm']))
        
        #     at-the-money option (ATM)
        df = df.withColumn("d1_atm_cdf", norm_cdf(df['d1_atm']))
        df = df.withColumn("d2_atm_cdf", norm_cdf(df['d2_atm']))
                
        #     in-the-money option (ITM)
        df = df.withColumn("d1_itm_cdf", norm_cdf(df['d1_itm']))
        df = df.withColumn("d2_itm_cdf", norm_cdf(df['d2_itm']))
        
        # Calculating option prices with Black-Scholes-Model
        df = df.withColumn("optionPrice_otm", df["last_price"] * df["d1_otm_cdf"] - (df["last_price"]+20) * eu_exp * df["d2_otm_cdf"])
        df = df.withColumn("optionPrice_atm", df["last_price"]*df["d1_atm_cdf"] - (df["last_price"]) * eu_exp * df["d2_atm_cdf"])
        df = df.withColumn("optionPrice_itm", df["last_price"]*df["d1_itm_cdf"] - (df["last_price"]-20) * eu_exp * df["d2_itm_cdf"])
        
        # Register table for SQL usage
        df.registerTempTable("stocks")
        
        ## Select whole data
        #stocks_df = sql_context.sql("select * from stocks")
        
        ## Select relevant data only
        stocks_df = sql_context.sql("select ticker, updated_on, last_price, prev_price, optionPrice_otm, \
                                     optionPrice_atm, optionPrice_itm from stocks")
        
        #  show df
        stocks_df.show(truncate=False)

        # write the resulting df to databse with pymongo and MongoDB Spark Connector
        write_mongo(stocks_df)
        
    # print errors in the output, in order to not stop the notebook
    except:
        e = sys.exc_info()[0]
        print("Process Error: %s" % e)

# %%
#    Defining Kafka Stream
kafkaStream1 = KafkaUtils.createStream(ssc, 'localhost:2181', groupId='spark-streaming-consumer', topics={'data1': 1})

# %%
#    Input stream from producer with (lambda :  json.loads)
parsed_hist = kafkaStream1.map(lambda v: json.loads(v[1]))
#    Call previously defined function "getOptionPrices"
parsed_hist.foreachRDD(getOptionPrices)
#    Starting stream processing
ssc.start()
ssc.awaitTermination()
# Out:
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:16:44.463Z|318.89    |318.975   |1.5005144896275198|7.551152711650815 |21.469603546277938|
# |AAPL  |2020-02-07T20:16:55.340Z|318.89    |318.89    |1.5005144896275198|7.551152711650815 |21.469603546277938|
# |AAPL  |2020-02-07T20:17:06.221Z|318.745   |318.89    |1.498516501580518 |7.547719185534646 |21.467705103309413|
# |AAPL  |2020-02-07T20:17:17.734Z|318.705   |318.685   |1.4979655009836819|7.5467720059163526|21.467181576451082|
# |AAPL  |2020-02-07T20:17:29.469Z|318.705   |318.705   |1.4979655009836819|7.5467720059163526|21.467181576451082|
# |TSLA  |2020-02-07T20:17:56.607Z|744.96    |744.0     |9.526912343562657 |17.64027321042181 |29.377021682197665|
# |TSLA  |2020-02-07T20:18:08.089Z|744.69    |744.96    |9.521140518051936 |17.633879747998492|29.371274897299884|
# |TSLA  |2020-02-07T20:18:18.964Z|744.69    |744.69    |9.521140518051936 |17.633879747998492|29.371274897299884|
# |TSLA  |2020-02-07T20:18:30.195Z|744.17    |744.69    |9.510025603069806 |17.621566412961215|29.360208279383528|
# |TSLA  |2020-02-07T20:18:41.463Z|744.17    |744.17    |9.510025603069806 |17.621566412961215|29.360208279383528|
# |TSLA  |2020-02-07T20:18:52.582Z|744.17    |744.17    |9.510025603069806 |17.621566412961215|29.360208279383528|
# |TSLA  |2020-02-07T20:19:02.793Z|744.17    |744.17    |9.510025603069806 |17.621566412961215|29.360208279383528|
# |TSLA  |2020-02-07T20:19:14.086Z|744.11    |744.17    |9.508743214082898 |17.62014564353376 |29.3589314691323  |
# |TSLA  |2020-02-07T20:19:25.220Z|744.11    |744.11    |9.508743214082898 |17.62014564353376 |29.3589314691323  |
# |TSLA  |2020-02-07T20:19:35.143Z|744.11    |744.11    |9.508743214082898 |17.62014564353376 |29.3589314691323  |
# |TSLA  |2020-02-07T20:19:46.391Z|744.11    |744.11    |9.508743214082898 |17.62014564353376 |29.3589314691323  |
# |TSLA  |2020-02-07T20:19:57.488Z|744.59    |744.11    |9.519002912332013 |17.631511798952886|29.36914657224486 |
# |AAPL  |2020-02-07T20:21:13.989Z|318.42    |318.39    |1.49404173300546  |7.540023351136313 |21.463453721986752|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:21:24.967Z|318.42    |318.42    |1.49404173300546|7.540023351136313|21.463453721986752|
# +------+------------------------+----------+----------+----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:21:36.370Z|318.595   |318.42    |1.4964506253115744|7.544167261966152|21.46574228261443|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:21:47.327Z|318.535   |318.595   |1.4956245620028454|7.542746492538782|21.46495746372574|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:21:58.333Z|318.535   |318.535   |1.4956245620028454|7.542746492538782|21.46495746372574 |
# |AAPL  |2020-02-07T20:22:09.373Z|318.48    |318.535   |1.494867481546919 |7.54144412056371 |21.464238201796775|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+----------------+------------------+
# |AAPL  |2020-02-07T20:22:20.223Z|318.48    |318.48    |1.494867481546919|7.54144412056371|21.464238201796775|
# +------+------------------------+----------+----------+-----------------+----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:22:31.222Z|318.46    |318.48    |1.4945922137799457|7.540970530754549|21.46397668886408|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:22:42.160Z|318.46    |318.46    |1.4945922137799457|7.540970530754549|21.46397668886408|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+---------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm|optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+---------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:22:53.019Z|318.45    |318.46    |1.494454586741 |7.540733735849983|21.463845939770806|
# +------+------------------------+----------+----------+---------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:23:03.918Z|318.38    |318.45    |1.4934913252578355|7.539076171518019|21.462930833775204|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:23:14.910Z|318.26    |318.38    |1.4918405403467503|7.536234632663252|21.461362641310473|
# |AAPL  |2020-02-07T20:23:25.890Z|318.26    |318.26    |1.4918405403467503|7.536234632663252|21.461362641310473|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:23:36.732Z|318.26    |318.26    |1.4918405403467503|7.536234632663252|21.461362641310473|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:23:47.676Z|318.29    |318.26    |1.4922531749184813|7.536945017376951|21.461754623011586|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:23:58.508Z|318.31    |318.29    |1.4925282874716643|7.537418607186083|21.462015968746982|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:24:09.393Z|318.32    |318.31    |1.4926658505990318|7.537655402090678|21.46214664899435|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:24:20.347Z|318.285   |318.32    |1.492184399634894|7.536826619924682|21.461689289652725|
# |AAPL  |2020-02-07T20:24:31.300Z|318.285   |318.285   |1.492184399634894|7.536826619924682|21.461689289652725|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:24:42.147Z|318.285   |318.285   |1.492184399634894|7.536826619924682|21.461689289652725|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:24:53.113Z|318.485   |318.285   |1.4949363013403811|7.541562518015951|21.464303583101866|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:25:03.990Z|318.56    |318.485   |1.4959687350965964|7.543338479800184|21.465284450103184|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:25:14.911Z|318.495   |318.56    |1.4950739443490306|7.541799312920517|21.464434349398175|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+----------------+------------------+
# |AAPL  |2020-02-07T20:25:25.758Z|318.57    |318.495   |1.4961064123151147|7.54357527470475|21.465415253251706|
# |AAPL  |2020-02-07T20:25:36.664Z|318.57    |318.57    |1.4961064123151147|7.54357527470475|21.465415253251706|
# +------+------------------------+----------+----------+------------------+----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+----------------+------------------+
# |AAPL  |2020-02-07T20:25:47.619Z|318.57    |318.57    |1.4961064123151147|7.54357527470475|21.465415253251706|
# +------+------------------------+----------+----------+------------------+----------------+------------------+
#
# Process Error: <class 'ValueError'>
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:26:03.939Z|318.64    |318.57    |1.497070280514734|7.545232839036714|21.466331012824583|
# |AAPL  |2020-02-07T20:26:14.212Z|318.64    |318.64    |1.497070280514734|7.545232839036714|21.466331012824583|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:26:25.623Z|318.68    |318.64    |1.4976211626318232|7.546180018654951|21.46685441204687|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:26:36.618Z|318.68    |318.68    |1.4976211626318232|7.546180018654951|21.46685441204687|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:26:47.509Z|318.675   |318.68    |1.4975522983792402|7.546061621202682|21.466788982848016|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:26:58.624Z|318.7     |318.675   |1.497896631034898|7.546653608464112|21.467116141115696|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:27:09.547Z|318.66    |318.7     |1.4973457124576939|7.545706428845847|21.4665927026158  |
# |AAPL  |2020-02-07T20:27:20.542Z|318.7     |318.66    |1.497896631034898 |7.546653608464112|21.467116141115696|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:27:31.413Z|318.65    |318.7     |1.4972079942071872|7.545469633941281|21.466461855265095|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:27:42.340Z|318.59    |318.65    |1.4963817804323867|7.544048864513911|21.465676874285748|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:27:55.630Z|318.665   |318.59    |1.49741457329214|7.545824826298144|21.46665812813245|
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:28:06.729Z|318.635   |318.665   |1.4970014253778459|7.545114441584417|21.466265593445826|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:28:21.236Z|318.595   |318.605   |1.4964506253115744|7.544167261966152|21.46574228261443|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:28:34.009Z|318.65    |318.635   |1.4972079942071872|7.545469633941281|21.466461855265095|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:28:44.923Z|318.555   |318.65    |1.495899898197493|7.543220082347915|21.46521905037116|
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:28:55.843Z|318.53    |318.555   |1.49555573080481|7.542628095086513|21.46489207013508|
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:29:06.883Z|318.425   |318.53    |1.4941105391089593|7.5401417485885815|21.463519088544842|
# |AAPL  |2020-02-07T20:29:18.105Z|318.425   |318.425   |1.4941105391089593|7.5401417485885815|21.463519088544842|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:29:28.965Z|318.29    |318.425   |1.4922531749184813|7.536945017376951|21.461754623011586|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:29:39.834Z|318.3     |318.29    |1.4923907289114098|7.537181812281517|21.461885293419357|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:29:53.109Z|318.25    |318.3     |1.4917030046260606|7.535997837758686|21.461231990585134|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:30:04.548Z|318.255   |318.25    |1.4917717719153316|7.536116235210983|21.461297315332615|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:30:15.460Z|318.27    |318.255   |1.49197808063591|7.536471427567818|21.46149329695686|
# +------+------------------------+----------+----------+----------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:30:26.584Z|318.395   |318.27    |1.493697719604235|7.539431363874911|21.463126907634773|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:30:39.843Z|318.395   |318.395   |1.493697719604235|7.539431363874911|21.463126907634773|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:30:50.761Z|318.38    |318.395   |1.4934913252578355|7.539076171518019|21.462930833775204|
# |AAPL  |2020-02-07T20:31:01.692Z|318.52    |318.435   |1.49541807182964  |7.542391300181919|21.46476128663926 |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:31:12.620Z|318.65    |318.52    |1.4972079942071872|7.545469633941281|21.466461855265095|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:31:23.549Z|318.61    |318.65    |1.4966571667882533|7.544522454322987|21.465938514967547|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm |
# +------+------------------------+----------+----------+------------------+-----------------+----------------+
# |AAPL  |2020-02-07T20:31:34.385Z|318.66    |318.61    |1.4973457124576939|7.545706428845847|21.4665927026158|
# +------+------------------------+----------+----------+------------------+-----------------+----------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:31:45.328Z|318.7     |318.66    |1.497896631034898|7.546653608464112|21.467116141115696|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:31:56.261Z|318.695   |318.7     |1.4978277622252705|7.546535211011786|21.46705070700756|
# |AAPL  |2020-02-07T20:32:07.155Z|318.68    |318.695   |1.4976211626318232|7.546180018654951|21.46685441204687|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:32:18.906Z|318.58    |318.6     |1.4962440940937753|7.5438120696093165|21.465546061312637|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+---------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm|
# +------+------------------------+----------+----------+------------------+-----------------+---------------+
# |AAPL  |2020-02-07T20:32:29.827Z|318.72    |318.58    |1.4981721176648293|7.547127198273245|21.46737788982 |
# +------+------------------------+----------+----------+------------------+-----------------+---------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:32:40.718Z|318.73    |318.72    |1.4983098678142213|7.547363993177754|21.467508771534767|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:32:51.687Z|318.97    |318.73    |1.5016172375612058|7.553047070887345|21.470651404469265|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:33:02.604Z|318.87    |318.97    |1.500238848155334|7.550679121841682|21.46934163076088|
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:33:13.512Z|318.9     |318.87    |1.5006523171912534|7.551389506555381|21.469734511392005|
# |AAPL  |2020-02-07T20:33:24.495Z|318.95    |318.95    |1.501341523275272 |7.552573481078184|21.470389410507323|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:33:36.593Z|319.08    |318.95    |1.5031339913677328|7.555651814837546|21.47209272165327|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:33:48.587Z|319.09    |319.08    |1.5032719053623467|7.555888609742112|21.47222377988419|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+------------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+------------------+-----------------+
# |AAPL  |2020-02-07T20:34:02.139Z|319.11    |319.09    |1.5035477469903356|7.5563621995512165|21.47248591103994|
# +------+------------------------+----------+----------+------------------+------------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+------------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+------------------+-----------------+
# |AAPL  |2020-02-07T20:34:16.890Z|319.11    |319.11    |1.5035477469903356|7.5563621995512165|21.47248591103994|
# +------+------------------------+----------+----------+------------------+------------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:34:27.875Z|319.4     |319.11    |1.5075494928601003|7.563229251783611|21.476289013147607|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+----------------+-----------------+
# |AAPL  |2020-02-07T20:34:38.768Z|319.295   |319.4     |1.5061001437700412|7.56074290528565|21.47491155264754|
# +------+------------------------+----------+----------+------------------+----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:34:49.723Z|319.2     |319.23    |1.5047892593027967|7.558493353692313|21.47366574363957|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:35:00.606Z|319.26    |319.2     |1.5056171386433164|7.5599141231196825|21.474452518997794|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:35:14.171Z|319.26    |319.26    |1.5056171386433164|7.5599141231196825|21.474452518997794|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:35:26.430Z|319.26    |319.26    |1.5056171386433164|7.5599141231196825|21.474452518997794|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:35:37.781Z|319.26    |319.26    |1.5056171386433164|7.5599141231196825|21.474452518997794|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:35:48.733Z|319.16    |319.26    |1.5042374306071977|7.557546174074048|21.473141324632365|
# |AAPL  |2020-02-07T20:35:59.656Z|319.16    |319.16    |1.5042374306071977|7.557546174074048|21.473141324632365|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:36:10.625Z|319.16    |319.16    |1.5042374306071977|7.557546174074048|21.473141324632365|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:36:21.517Z|319.16    |319.16    |1.5042374306071977|7.557546174074048|21.473141324632365|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:36:32.463Z|319.175   |319.16    |1.504444357848051|7.557901366430883|21.473337972580623|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:36:43.352Z|319.17    |319.175   |1.5043753809650298|7.557782968978643|21.47327242204051|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:36:54.376Z|319.18    |319.17    |1.5045133358671166|7.5580197638831805|21.473403524344576|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:37:07.109Z|319.18    |319.18    |1.5045133358671166|7.5580197638831805|21.473403524344576|
# |AAPL  |2020-02-07T20:37:18.271Z|319.1     |319.18    |1.5034098239033042|7.55612540464665  |21.472354843013193|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+----------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:37:29.319Z|318.995   |319.1     |1.50196190600942|7.553639058148747|21.470978924491988|
# +------+------------------------+----------+----------+----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:37:42.052Z|319.0     |319.0     |1.5020308431108376|7.553757455601016|21.471044432172164|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:37:54.324Z|319.0     |319.0     |1.5020308431108376|7.553757455601016|21.471044432172164|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:38:05.235Z|319.0     |319.0     |1.5020308431108376|7.553757455601016|21.471044432172164|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm |
# +------+------------------------+----------+----------+------------------+-----------------+----------------+
# |AAPL  |2020-02-07T20:38:16.098Z|319.06    |319.06    |1.5028581770186022|7.555178225028442|21.4718306198871|
# +------+------------------------+----------+----------+------------------+-----------------+----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:38:27.055Z|319.04    |319.06    |1.5025823808579801|7.554704635219281|21.471568537716678|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# ...
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:54:34.103Z|319.52    |319.49    |1.5092065044460483|7.566070790638349|21.47786391379674|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:54:45.000Z|319.67    |319.52    |1.5112786871959898|7.569622714206844|21.479833529028724|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:54:55.931Z|319.61    |319.67    |1.510449691710484|7.568201944779446|21.47904555106504|
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:55:06.868Z|319.61    |319.61    |1.510449691710484|7.568201944779446|21.47904555106504|
# |AAPL  |2020-02-07T20:55:18.045Z|319.61    |319.61    |1.510449691710484|7.568201944779446|21.47904555106504|
# +------+------------------------+----------+----------+-----------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:55:29.258Z|319.96    |319.61    |1.5152877971323662|7.576489766439181|21.483644565825557|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:55:40.182Z|319.86    |319.96    |1.5139049153931765|7.5741218173935465|21.482329951815927|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:55:51.124Z|319.92    |319.86    |1.5147345901427087|7.575542586820944|21.48311866171565|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:56:02.064Z|319.91    |319.92    |1.5145962997054383|7.575305791916406|21.482987197875786|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:56:13.006Z|319.875   |319.91    |1.5141123188078254|7.574477009750382|21.48252711283351|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:56:23.959Z|319.84    |319.875   |1.5136283933478012|7.573648227584414|21.482067087528833|
# |AAPL  |2020-02-07T20:56:34.871Z|319.85    |319.84    |1.513766652107428 |7.57388502248898 |21.48219851723377 |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:56:45.816Z|319.9     |319.85    |1.5144580137927264|7.575068997011812|21.482855738911553|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:56:56.731Z|319.87    |319.9     |1.5140431832048833|7.574358612298113|21.48246139127508|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:57:07.569Z|319.88    |319.87    |1.5141814555421647|7.574595407202679|21.482592835610944|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:57:18.514Z|319.97    |319.88    |1.5154261101886064|7.576726561343776|21.48377605403931|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:57:29.457Z|319.97    |319.97    |1.5154261101886064|7.576726561343776 |21.48377605403931 |
# |AAPL  |2020-02-07T20:57:40.378Z|319.94    |319.97    |1.5150111845899303|7.5760161766300484|21.483381604021133|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:57:53.615Z|319.92    |319.94    |1.5147345901427087|7.575542586820944|21.48311866171565|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:58:04.587Z|319.91    |319.92    |1.5145962997054383|7.575305791916406|21.482987197875786|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:58:16.992Z|319.94    |319.91    |1.5150111845899303|7.5760161766300484|21.483381604021133|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:58:28.307Z|319.94    |319.94    |1.5150111845899303|7.5760161766300484|21.483381604021133|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm  |
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
# |AAPL  |2020-02-07T20:58:39.167Z|319.93    |319.94    |1.5148728851043103|7.575779381725511|21.48325013043086|
# +------+------------------------+----------+----------+------------------+-----------------+-----------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:58:50.090Z|319.91    |319.945   |1.5145962997054383|7.575305791916406|21.482987197875786|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:59:01.016Z|319.91    |319.91    |1.5145962997054383|7.575305791916406|21.482987197875786|
# |AAPL  |2020-02-07T20:59:11.932Z|319.89    |319.91    |1.5143197324048714|7.574832202107245|21.48272428482312 |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:59:22.836Z|319.84    |319.89    |1.5136283933478012|7.573648227584414|21.482067087528833|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm   |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+------------------+------------------+
# |AAPL  |2020-02-07T20:59:34.884Z|319.86    |319.84    |1.5139049153931765|7.5741218173935465|21.482329951815927|
# +------+------------------------+----------+----------+------------------+------------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:59:45.817Z|319.91    |319.86    |1.5145962997054383|7.575305791916406|21.482987197875786|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm   |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
# |AAPL  |2020-02-07T20:59:58.829Z|319.91    |319.88    |1.5145962997054383|7.575305791916406|21.482987197875786|
# +------+------------------------+----------+----------+------------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T21:00:09.658Z|320.03    |319.93    |1.516256083499826|7.578147330771145|21.484565085664883|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |ticker|updated_on              |last_price|prev_price|optionPrice_otm  |optionPrice_atm  |optionPrice_itm   |
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
# |AAPL  |2020-02-07T21:00:20.622Z|320.03    |320.03    |1.516256083499826|7.578147330771145|21.484565085664883|
# +------+------------------------+----------+----------+-----------------+-----------------+------------------+
#
# Process Error: <class 'NameError'>
